# %%
import glob
import os
files = glob.glob('D:/FYP/FYP html/*.html')

# %%
files
# Out:
# ["D:/FYP/FYP html\\'''soft computing'''0.html",
#  "D:/FYP/FYP html\\'''soft computing'''1.html",
#  "D:/FYP/FYP html\\'''soft computing'''10.html",
#  "D:/FYP/FYP html\\'''soft computing'''100.html",
#  "D:/FYP/FYP html\\'''soft computing'''101.html",
#  "D:/FYP/FYP html\\'''soft computing'''102.html",
#  "D:/FYP/FYP html\\'''soft computing'''103.html",
#  "D:/FYP/FYP html\\'''soft computing'''104.html",
#  "D:/FYP/FYP html\\'''soft computing'''105.html",
#  "D:/FYP/FYP html\\'''soft computing'''106.html",
#  "D:/FYP/FYP html\\'''soft computing'''107.html",
#  "D:/FYP/FYP html\\'''soft computing'''108.html",
#  "D:/FYP/FYP html\\'''soft computing'''109.html",
#  "D:/FYP/FYP html\\'''soft computing'''11.html",
#  "D:/FYP/FYP html\\'''soft computing'''110.html",
#  "D:/FYP/FYP html\\'''soft computing'''111.html",
#  "D:/FYP/FYP html\\'''soft computing'''112.html",
#  "D:/FYP/FYP html\\'''soft computing'''113.html",
#  "D:/FYP/FYP html\\'''soft computing'''114.html",
# ...

# %%
len(files)
# Out:
# 36483

# %%
import tqdm

# %%
from bs4 import BeautifulSoup
pbar = tqdm.tqdm(total = len(files))
for file in files:
    with open(file, "r", encoding='utf-8') as f:
        html= f.read()

    soup = BeautifulSoup(html, features="html.parser")
    filename = os.path.basename(file).replace('.html','')

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text()

    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    with open('D:/FYP txt//'+ filename +'.txt', 'w', encoding='utf-8') as f:
           f.write(text)
    pbar.update(1)
pbar.close()
# Out:
#   0%|                                                                              | 3/36483 [00:00<2:01:12,  5.02it/s]C:\Users\34683\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://ascelibrary.org/doi/full/10.1061/%28ASCE%29PS.1949-1204.0000449
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\34683\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.engpaper.net/soft-computing.html
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ...

# %%
from bs4 import BeautifulSoup
pbar = tqdm.tqdm(total = len(files))
for file in files:
    with open(file, "r", encoding='utf-8') as f:
        html= f.read()

    soup = BeautifulSoup(html, features="html.parser")
    filename = os.path.basename(file).replace('.html','')

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    heading_tags = ["h1", "h2", "h3"]
    text1 = ''
    text2 = ''
    for tags in soup.find_all(heading_tags):
        text1 = text1 + tags.name + ':' + tags.text.strip() + '\n'
    
    for p in soup.find_all("p"):
        text2 = text2 + p.text.strip()+'\n'
    #try:
       # text1 = soup.find_all('h').getText()
    #except AttributeError:
     #   text1 = ""
    #try:
    #    text2 = soup.find_all('p').getText()
    #except AttributeError:
     #   text2 = ""
    url = soup.get_text().split('\n')[0]
    text = url + '\n' + text1 + text2
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    with open('D:/FYP/FYP txt p&h//'+ filename +'.txt', 'w', encoding='utf-8') as f:
           f.write(text)
    pbar.update(1)
pbar.close()
# Out:
# ...
#   1%|▍                                                                           | 214/36483 [00:44<5:37:26,  1.79it/s]C:\Users\34683\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://levelup.gitconnected.com/abstract-data-types-ece216eab728
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
#   1%|▍                                                                           | 221/36483 [00:48<6:56:10,  1.45it/s]C:\Users\34683\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "http://www.cs.unc.edu/~stotts/danish/web/userman/umadt.html
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ...

# %%
from bs4 import BeautifulSoup
pbar = tqdm.tqdm(total = len(files))
for file in files:
    with open(file, "r", encoding='utf-8') as f:
        html= f.read()

    soup = BeautifulSoup(html, features="html.parser")
    filename = os.path.basename(file).replace('.html','')

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    heading_tags = ["title"]
    text1 = ''
    text2 = ''
    for tags in soup.find_all(heading_tags):
        text1 = text1 + tags.name + ':' + tags.text.strip() + '\n'
    
    try:
        for p in soup.find_all("abstract"):
            text2 = text2 + p.text.strip()+'\n'
    except:
        text2 = ''
    #try:
       # text1 = soup.find_all('h').getText()
    #except AttributeError:
     #   text1 = ""
    #try:
    #    text2 = soup.find_all('p').getText()
    #except AttributeError:
     #   text2 = ""
    url = soup.get_text().split('\n')[0]
    text = url + '\n' + text1 + text2
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    with open('D:/FYP/FYP txt title&abstract//'+ filename +'.txt', 'w', encoding='utf-8') as f:
           f.write(text)
    pbar.update(1)
pbar.close()
# Out:
# ...
#   0%|▏                                                                              | 91/36483 [00:07<55:30, 10.93it/s]C:\Users\34683\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.tandfonline.com/action/journalInformation?show=aimsScope&journalCode=tasj20
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\34683\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.routledge.com/Applied-Soft-Computing-Techniques-and-Applications/Borah-Panigrahi/p/book/9781774630297
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ...

# %%
print(soup.find(string='https'))
# Out:
# None

# %%
soup.get_text().split('\n')[0]
# Out:
# 'http://veritaspericias.com/5xx6wd/neural-network-ea.html'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
import html2text

req = Request("https://en.wikipedia.org/wiki/Python_(programming_language)")
html_page = urlopen(req)

soup = BeautifulSoup(html_page, "html.parser")

# soup is a BeautifulSoup object Type which contains HTML

h = html2text.HTML2Text()
h.ignore_links = True

f = open("html_text.txt", "w")         # Creating html_text.txt File

for line in h.handle(str(soup)):       # handle() Function only accepts string as parameter
	f.write(line)                      # That's why converted soup object to string str(soup)

f.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8009a1a921e2> in <module>
#       2 from urllib.request import Request, urlopen
#       3 import re
# ----> 4 import html2text
#       5
#       6 req = Request("https://en.wikipedia.org/wiki/Python_(programming_language)")
#
# ModuleNotFoundError: No module named 'html2text'

# %%
pip install html2text
# Out:
# Could not fetch URL https://pypi.org/simple/html2text/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/html2text/ (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1125)'))) - skipping
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1125)'))) - skipping
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1125)'))': /simple/html2text/
# ...
